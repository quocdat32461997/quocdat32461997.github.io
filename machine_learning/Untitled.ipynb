# %% [markdown]
# # Linear Regression

# %%
#import dependencies
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot([1, 2], [4,7])
plt.title("Linear Regression: y = wx + b")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()
